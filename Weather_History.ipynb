# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import sklearn.metrics as sm

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("weatherHistory.csv")
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
#Categorical variables:
categorical = df.select_dtypes(include = ["object"]).keys()
print(categorical)
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Daily Summary'], dtype='object')

# %%
#Quantitative variables:
quantitative = df.select_dtypes(include = ["int64","float64"]).keys()
print(quantitative)
# Out:
# Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Loud Cover', 'Pressure (millibars)'],
#       dtype='object')

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
df[quantitative].describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 9, 9
df[quantitative].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000232AC8C46C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000232AD429908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000232AC7ED308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002328BEBF788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000232A60980C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002328CB02B88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000232A604E7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000232A608AF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000232A664D488>]],
#       dtype=object)

# %%
df=df.drop('Loud Cover',axis=1) #'Loud Cover' takes values zero

# %%
pd.isnull(df).sum() > 0
# Out:
# Formatted Date              False
# Summary                     False
# Precip Type                  True
# Temperature (C)             False
# Apparent Temperature (C)    False
# Humidity                    False
# Wind Speed (km/h)           False
# Wind Bearing (degrees)      False
# Visibility (km)             False
# Pressure (millibars)        False
# Daily Summary               False
# dtype: bool

# %%
# fill missing values with mode column values
df['Precip Type'] = df['Precip Type'].fillna(df['Precip Type'].mode()[0])

# %%
pressure_median = df['Pressure (millibars)'].median()
      
def pressure(x):
    if x==0:
        return x + pressure_median
    else:
        return x
        
df["Pressure (millibars)"] = df.apply(lambda row:pressure(row["Pressure (millibars)"]) , axis = 1)

rcParams['figure.figsize'] = 5, 3
df['Pressure (millibars)'].hist()

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 8, 5
sns.countplot(y=df['Summary'])

# %%
df['Daily Summary'].value_counts(dropna=False)
# Out:
# Mostly cloudy throughout the day.                                                                                           20085
# Partly cloudy throughout the day.                                                                                            9981
# Partly cloudy until night.                                                                                                   6169
# Partly cloudy starting in the morning.                                                                                       5184
# Foggy in the morning.                                                                                                        4201
#                                                                                                                             ...
# Breezy overnight and partly cloudy throughout the day.                                                                         24
# Breezy and foggy until morning.                                                                                                24
# Partly cloudy starting overnight continuing until morning and breezy starting in the morning continuing until afternoon.       24
# Breezy starting in the afternoon continuing until night and mostly cloudy starting in the evening.                             24
# Foggy starting overnight continuing until morning and breezy in the afternoon.                                                 23
# Name: Daily Summary, Length: 214, dtype: int64

# %%
df['Summary'].value_counts(dropna=False)
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Windy and Mostly Cloudy                   35
# Breezy and Foggy                          35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# Windy                                      8
# Humid and Overcast                         7
# Windy and Foggy                            4
# Breezy and Dry                             1
# Dangerously Windy and Partly Cloudy        1
# Windy and Dry                              1
# Name: Summary, dtype: int64

# %%
df['Precip Type'].value_counts(dropna=False)
# Out:
# rain    85741
# snow    10712
# Name: Precip Type, dtype: int64

# %%
sns.countplot(x=df['Precip Type'])

# %%
plt.figure(figsize=(18,8)) 
sns.pairplot(df[['Temperature (C)', 'Humidity' ]])
plt.show()

# %%
plt.figure(figsize=(18,8)) # this creates a figure 8 inch wide, 4 inch high
sns.pairplot(df[['Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)']])
plt.show()

# %%
new_df = df.copy()

# %%
new_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# 1                   259.0          15.8263               1015.63
# 2                   204.0          14.9569               1015.94
# 3                   269.0          15.8263               1016.41
# 4                   259.0          15.8263               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
standardSacler = StandardScaler()
col_to_scale = ['Temperature (C)','Wind Speed (km/h)']
df[col_to_scale] = standardSacler.fit_transform(df[col_to_scale])
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain        -0.257599
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain        -0.269814
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain        -0.267487
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain        -0.381489
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain        -0.332631
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89           0.478635
# 1                  7.227778      0.86           0.499594
# 2                  9.377778      0.89          -0.995473
# 3                  5.944444      0.83           0.476306
# 4                  6.977778      0.83           0.033841
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)  \
# 0                   251.0          15.8263               1015.13
# 1                   259.0          15.8263               1015.63
# 2                   204.0          14.9569               1015.94
# 3                   269.0          15.8263               1016.41
# 4                   259.0          15.8263               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
ls = linear_model.LinearRegression()

column = ['Wind Speed (km/h)','Temperature (C)']
X = df[column]
y = new_df["Humidity"]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.40, shuffle=True, random_state=0)
ls.fit(X_train, y_train)
y_pred = ls.predict(X_test)
print(y_pred)
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred), 2))
# Out:
# [0.74819185 0.69904567 0.59966579 ... 0.76914534 0.7196986  0.65354965]
# Mean absolute error = 0.12
# Mean squared error = 0.02
# Median absolute error = 0.1
# Explain variance score = 0.44
# R2 score = 0.44

# %%
ls = linear_model.LinearRegression()

X = df["Temperature (C)"].values.reshape(-1,1)
y = df["Humidity"].values.reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.40, shuffle=True, random_state=0)
print("Linear Regression")
ls.fit(X_train, y_train)
y_pred = ls.predict(X_test)
print("MSE = ",mean_squared_error(y_test, y_pred))
print("R2 = ",r2_score(y_test, y_pred))
# Out:
# Linear Regression
# MSE =  0.022898572405010587
# R2 =  0.3987357305602758
